# %% [markdown]
# <a href="https://colab.research.google.com/github/alishas2005/PRODIGY/blob/main/PRODIGY_GA_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install markovify
# !pip install weasyprint
# !pip install --upgrade weasyprint

# %%
import markovify
import markdown
import random
from weasyprint import HTML , CSS
from weasyprint.text.fonts import FontConfiguration

# %% [markdown]
# The Markovify module needs a string to process and build a database of sequential probability sequences, so start with some book like Midnight's Children.The following code assumes that this novel's text has already been uploaded into the notebook's file storage area with the file name book.txt and story.txt.

# %%
import markovify

# Get raw text as string.
with open("/content/book.txt") as f:
  text = f.read()

with open("/content/story.txt") as f:
  text2 = f.read() # use a different variable name to avoid overwriting

text += text2 # combine both texts

novel = ''
while len(novel.split(" ")) < 50000:
    # Indent the code block within the while loop
    # Check if the file was read correctly
    if not text:  # Check if text is empty
        print("Error: The file is empty or could not be read.")
        break # exit the loop if no text
    else:
        # Build the model.
        text_model = markovify.Text(text)

        # Print five randomly-generated sentences
        for i in range(4):
          sentence = text_model.make_sentence()
          if sentence: # check if a sentence was generated
            novel += sentence
            novel += "\n"
print(novel)
#Print three randomly-generated sentences of no more than 280 characters
#for i in range(3):
  #print(text_model.make_short_sentence(280))
# Out:
# Midnight's Children is a postcolonial, postmodern and magical realist story told by its chief protagonist, Saleem Sinai, born at the exact moment when India became an independent country.
# The protagonist and narrator of the story is Saleem Sinai, set in the context of historical events.
# Midnight's Children is a postcolonial, postmodern and magical realist story told by its chief protagonist, Saleem Sinai, born at the exact moment when India became an independent country.
# Midnight's Children is a postcolonial, postmodern and magical realist story told by its chief protagonist, Saleem Sinai, born at the exact moment when India became an independent country.
# The first book begins with the story is Saleem Sinai, set in the context of historical events.
# The protagonist and narrator of the story is Saleem Sinai, set in the context of historical events.
# The first book begins with the story of the story is Saleem Sinai, set in the context of historical events.
# ...
